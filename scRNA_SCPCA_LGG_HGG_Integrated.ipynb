# %% [markdown]
# <a href="https://colab.research.google.com/github/rs25-code/scRNA/blob/main/scRNA_SCPCA_LGG_HGG_Integrated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scanpy
# Out:
# Collecting scanpy
#   Downloading scanpy-1.9.6-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 7.8 MB/s eta 0:00:00
# Collecting anndata>=0.7.4 (from scanpy)
#   Downloading anndata-0.10.3-py3-none-any.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.2/119.2 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=3 in /usr/local/lib/python3.10/dist-packages (from scanpy) (3.9.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.3.2)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.10/dist-packages (from scanpy) (3.7.1)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.10/dist-packages (from scanpy) (3.2.1)
# Requirement already satisfied: numba>=0.41.0 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.58.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from scanpy) (23.2)
# Requirement already satisfied: pandas!=2.1.2,>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.5.3)
# Requirement already satisfied: patsy in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.5.4)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.2.2)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.11.4)
# Requirement already satisfied: seaborn!=0.13.0 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.12.2)
# Collecting session-info (from scanpy)
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.14.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from scanpy) (4.66.1)
# Collecting umap-learn>=0.3.10 (from scanpy)
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting array-api-compat (from anndata>=0.7.4->scanpy)
#   Downloading array_api_compat-1.4-py3-none-any.whl (29 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anndata>=0.7.4->scanpy) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->scanpy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->scanpy) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->scanpy) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->scanpy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->scanpy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->scanpy) (2.8.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.41.0->scanpy) (0.41.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=2.1.2,>=1.1.1->scanpy) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24->scanpy) (3.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy->scanpy) (1.16.0)
# Collecting pynndescent>=0.5 (from umap-learn>=0.3.10->scanpy)
#   Downloading pynndescent-0.5.11-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 4.4 MB/s eta 0:00:00
# Collecting stdlib_list (from session-info->scanpy)
#   Downloading stdlib_list-0.10.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 6.4 MB/s eta 0:00:00
# Building wheels for collected packages: umap-learn, session-info
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=ddb22edef3a1e79ade026917dad610af4186e0a0ff35bde2f258bd79faa3dc6a
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8027 sha256=14fb1c50829a54744cf9b89f97a88d498dcc5d7b9cbe490a40a475073871b81a
#   Stored in directory: /root/.cache/pip/wheels/6a/aa/b9/eb5d4031476ec10802795b97ccf937b9bd998d68a9b268765a
# Successfully built umap-learn session-info
# Installing collected packages: stdlib_list, array-api-compat, session-info, pynndescent, anndata, umap-learn, scanpy
# Successfully installed anndata-0.10.3 array-api-compat-1.4 pynndescent-0.5.11 scanpy-1.9.6 session-info-1.0.0 stdlib_list-0.10.0 umap-learn-0.5.5

# %%
# !pip install scikit-misc
# Out:
# Collecting scikit-misc
#   Downloading scikit_misc-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from scikit-misc) (1.23.5)
# Installing collected packages: scikit-misc
# Successfully installed scikit-misc-0.3.1

# %%
import csv
import gzip
import os
import numpy as np
import pandas as pd
import seaborn as sns
import scanpy as sc
import anndata as ad

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def pp(dir_path, sample, grade):
    print("Processing " + dir_path)
    adata = sc.read_10x_mtx(path=dir_path, var_names='gene_ids', cache=True)
    adata.obs['Sample'] = grade + sample
    sc.pp.calculate_qc_metrics(adata, percent_top=None, log1p=False, inplace=True)
    sc.pp.filter_genes(adata, min_cells=3)
    upper_lim = np.quantile(adata.obs.n_genes_by_counts.values, .98)
    adata = adata[adata.obs.n_genes_by_counts < upper_lim]

    return adata

# %%
out = []
for dir in os.listdir('/content/drive/MyDrive/Transcriptomics/SCPC-2/'):
    out.append(pp('/content/drive/MyDrive/Transcriptomics/SCPC-2/' + dir, dir, 'LGG-'))
# Out:
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000048
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000043
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000044
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000042
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000049
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000041
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000047
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000045
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000046
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000024
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000031
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000028
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000032
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000026
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000029
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000027
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000033
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000034
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000030
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000025
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000037
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000040
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000036
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000038
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000035
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Processing /content/drive/MyDrive/Transcriptomics/SCPC-2/SCPCL000039
# /usr/local/lib/python3.10/dist-packages/anndata/__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(

# %%
adata = sc.concat(out)
# Out:
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:1897: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
adata.X
# Out:
# <47485x2427 sparse matrix of type '<class 'numpy.float32'>'
# 	with 38404236 stored elements in Compressed Sparse Row format>

# %%
adata.obs_names_make_unique()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 47485 × 2427
#     obs: 'Sample', 'n_genes_by_counts', 'total_counts'

# %%
adata.obs
# Out:
#                              Sample  n_genes_by_counts  total_counts
# AAGCGAGGTTGTCCCT    LGG-SCPCL000048               8453  36775.000000
# GGCTTGGGTTGTAGCT    LGG-SCPCL000048               8447  37379.996094
# TGACCCTCACTTTATC    LGG-SCPCL000048               8389  37204.968750
# CTCCCTCTCTCGGTCT    LGG-SCPCL000048               8174  36409.980469
# TAACGACGTAACCCTA    LGG-SCPCL000048               8352  38080.906250
# ...                             ...                ...           ...
# AGATCGTGTGTAGCAG    LGG-SCPCL000039                490   1329.999878
# TGGAACTGTTCCTACC-3  LGG-SCPCL000039                533    579.000061
# GACACGCTCTATACGG    LGG-SCPCL000039               2316   7271.997559
# ATGCATGCACATATGC    LGG-SCPCL000039               2257   5830.999023
# TCCGTGTTCTGGCCAG    LGG-SCPCL000039                386    741.000000
#
# [47485 rows x 3 columns]

# %%
adata.write_h5ad('/content/drive/MyDrive/Transcriptomics/SCPC/lgg-combined.h5ad')

# %%
adata.shape
# Out:
# (47485, 2427)

# %%
adata.X
# Out:
# <47485x2427 sparse matrix of type '<class 'numpy.float32'>'
# 	with 38404236 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Preprocessing

# %%
sc.pp.calculate_qc_metrics(adata, percent_top=None, log1p=False, inplace=True)

# %%
adata.var.sort_values('n_cells_by_counts')
# Out:
#                  n_cells_by_counts  mean_counts  pct_dropout_by_counts  \
# ENSG00000251138                365     0.006222              99.231336
# ENSG00000188451                456     0.005957              99.039697
# ENSG00000233926                463     0.008465              99.024955
# ENSG00000286133                486     0.008634              98.976519
# ENSG00000287516                681     0.010217              98.565863
# ...                            ...          ...                    ...
# ENSG00000198938              46461     5.029130               2.156470
# ENSG00000211459              46628     4.854908               1.804780
# ENSG00000280441              46741     5.187600               1.566811
# ENSG00000198899              46787     5.113083               1.469938
# ENSG00000210082              47363     5.882837               0.256923
#
#                   total_counts
# ENSG00000251138     295.450073
# ENSG00000188451     282.855988
# ENSG00000233926     401.952026
# ENSG00000286133     409.978149
# ENSG00000287516     485.162445
# ...                        ...
# ENSG00000198938  238807.421875
# ENSG00000211459  230535.562500
# ENSG00000280441  246332.625000
# ENSG00000198899  242795.031250
# ENSG00000210082  279346.000000
#
# [2427 rows x 4 columns]

# %%
sc.pp.filter_genes(adata, min_cells=1000)

# %%
adata.var.sort_values('n_cells_by_counts')
# Out:
#                  n_cells_by_counts  mean_counts  pct_dropout_by_counts  \
# ENSG00000163689               1151     0.023259              97.576077
# ENSG00000164749               1186     0.023314              97.502369
# ENSG00000261419               1211     0.027801              97.449721
# ENSG00000286932               1267     0.013973              97.331789
# ENSG00000145934               1275     0.032870              97.314942
# ...                            ...          ...                    ...
# ENSG00000198938              46461     5.029130               2.156470
# ENSG00000211459              46628     4.854908               1.804780
# ENSG00000280441              46741     5.187600               1.566811
# ENSG00000198899              46787     5.113083               1.469938
# ENSG00000210082              47363     5.882837               0.256923
#
#                   total_counts  n_cells
# ENSG00000163689    1104.437256     1151
# ENSG00000164749    1107.074219     1186
# ENSG00000261419    1320.148193     1211
# ENSG00000286932     663.505371     1267
# ENSG00000145934    1560.840942     1275
# ...                        ...      ...
# ENSG00000198938  238807.421875    46461
# ENSG00000211459  230535.562500    46628
# ENSG00000280441  246332.625000    46741
# ENSG00000198899  242795.031250    46787
# ENSG00000210082  279346.000000    47363
#
# [2420 rows x 5 columns]

# %%
adata.obs.sort_values('n_genes_by_counts')
# Out:
#                            Sample  n_genes_by_counts  total_counts
# AAGATAGTCATCACTT  LGG-SCPCL000040                 86    365.126556
# GGATGTTTCGGACTTA  LGG-SCPCL000040                 89    370.141602
# TTTCATGCACCTTCCA  LGG-SCPCL000040                 94    393.614258
# CATTGTTTCTTTGCGC  LGG-SCPCL000040                 94    417.771790
# AATCGTGGTGCGGCTT  LGG-SCPCL000040                 95    414.287567
# ...                           ...                ...           ...
# TAGAGTCTCGACGCTG  LGG-SCPCL000037               2257   2719.770264
# TTAGTCTGTTGGACCC  LGG-SCPCL000037               2259   2805.868408
# AGGCATTTCGTGAGAG  LGG-SCPCL000037               2265   2766.642578
# AAGGAATGTTCGATTG  LGG-SCPCL000037               2267   2847.799316
# CGTTGGGAGGTTAGTA  LGG-SCPCL000037               2292   2872.905518
#
# [47485 rows x 3 columns]

# %%
sc.pl.highest_expr_genes(adata, n_top=20)

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts'],
             jitter=0.4, multi_panel=True)

# %%
upper_lim = np.quantile(adata.obs.n_genes_by_counts.values, .98)
#upper_lim = 3000

# %%
upper_lim
# Out:
# 1886.0

# %%
adata = adata[adata.obs.n_genes_by_counts < upper_lim]

# %%
adata.obs
# Out:
#                              Sample  n_genes_by_counts  total_counts
# TACGTCCCACGTGTGC    LGG-SCPCL000048               1870   2507.774170
# AGTTCGAGTCATATGC    LGG-SCPCL000048               1828   2478.082520
# GGGACTCTCCGAGATT    LGG-SCPCL000048               1883   2573.293701
# CAACAACCATACCATG    LGG-SCPCL000048               1868   2588.730469
# ATTTACCAGCTACTGT    LGG-SCPCL000048               1876   2563.078125
# ...                             ...                ...           ...
# AGATCGTGTGTAGCAG    LGG-SCPCL000039                205    555.123108
# TGGAACTGTTCCTACC-3  LGG-SCPCL000039                222    802.685364
# GACACGCTCTATACGG    LGG-SCPCL000039                729   1336.719482
# ATGCATGCACATATGC    LGG-SCPCL000039                801   1395.695068
# TCCGTGTTCTGGCCAG    LGG-SCPCL000039                215    696.223083
#
# [46534 rows x 3 columns]

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 46534 × 2420
#     obs: 'Sample', 'n_genes_by_counts', 'total_counts'
#     var: 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells'
#     uns: 'log1p'

# %% [markdown]
# # Normalization

# %%
adata.X.sum(axis = 1)
# Out:
# matrix([[2507.7742],
#         [2478.0825],
#         [2572.7175],
#         ...,
#         [1336.7195],
#         [1395.6951],
#         [ 696.2231]], dtype=float32)

# %%
sc.pp.normalize_total(adata, target_sum=1e4) #normalize every cell to 10,000 UMI
# Out:
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_normalization.py:169: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
adata.X.sum(axis = 1)
# Out:
# matrix([[10000.   ],
#         [10000.   ],
#         [ 9999.999],
#         ...,
#         [10000.001],
#         [ 9999.999],
#         [10000.   ]], dtype=float32)

# %%
sc.pp.log1p(adata) #change to log counts
# Out:
# WARNING: adata.X seems to be already log-transformed.

# %%
adata.X.sum(axis = 1)
# Out:
# matrix([[3239.3616],
#         [3213.7405],
#         [3275.1233],
#         ...,
#         [1903.7262],
#         [2026.7173],
#         [ 824.4016]], dtype=float32)

# %%
adata.raw = adata

# %%
adata.raw.X
# Out:
# <46534x2420 sparse matrix of type '<class 'numpy.float32'>'
# 	with 36487907 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Clustering

# %%
sc.pp.highly_variable_genes(adata, n_top_genes = 2000, subset = True, flavor = 'seurat_v3')
# Out:
# /usr/local/lib/python3.10/dist-packages/scanpy/preprocessing/_highly_variable_genes.py:61: UserWarning: `flavor='seurat_v3'` expects raw count data, but non-integers were found.
#   warnings.warn(

# %%
adata.var
# Out:
#                  n_cells_by_counts  mean_counts  pct_dropout_by_counts  \
# ENSG00000248527              24822     1.018837              47.726651
# ENSG00000187608               6882     0.190836              85.507002
# ENSG00000069424               6476     0.198984              86.362009
# ENSG00000171735              17610     0.561258              62.914605
# ENSG00000049246              10413     0.302123              78.070970
# ...                            ...          ...                    ...
# ENSG00000198840              43372     3.664448               8.661683
# ENSG00000212907              21533     0.719176              54.653048
# ENSG00000198786              42663     2.915776              10.154786
# ENSG00000198727              45560     4.412498               4.053912
# ENSG00000198695              17357     0.547554              63.447404
#
#                   total_counts  n_cells  highly_variable  \
# ENSG00000248527   48379.406250    24822             True
# ENSG00000187608    9061.861328     6882             True
# ENSG00000069424    9448.793945     6476             True
# ENSG00000171735   26651.400391    17610             True
# ENSG00000049246   14346.328125    10413             True
# ...                        ...      ...              ...
# ENSG00000198840  174007.062500    43372             True
# ENSG00000212907   34150.238281    21533             True
# ENSG00000198786  138455.171875    42663             True
# ENSG00000198727  209528.031250    45560             True
# ENSG00000198695   26000.509766    17357             True
#
#                  highly_variable_rank     means  variances  variances_norm
# ENSG00000248527                 419.0  1.286740   1.776796        1.073757
# ENSG00000187608                1523.0  0.276954   0.547175        0.974278
# ENSG00000069424                 478.0  0.298675   0.636906        1.062663
# ENSG00000171735                1363.0  0.786475   1.216475        0.983698
# ENSG00000049246                1385.0  0.441164   0.791529        0.982867
# ...                               ...       ...        ...             ...
# ENSG00000198840                  71.0  3.033968   1.097750        1.222727
# ENSG00000212907                1098.0  1.023640   1.455423        1.000589
# ENSG00000198786                1131.0  2.807751   1.119741        0.998442
# ENSG00000198727                 931.0  3.358805   0.642181        1.011733
# ENSG00000198695                 656.0  0.799376   1.301335        1.040581
#
# [2000 rows x 10 columns]

# %%
sc.pl.highly_variable_genes(adata)

# %%
adata = adata[:, adata.var.highly_variable]

# %%
sc.pp.regress_out(adata, ['total_counts'])

# %%
sc.pp.scale(adata, max_value=10)

# %%
sc.tl.pca(adata, svd_solver='arpack')

# %%
sc.pl.pca_variance_ratio(adata, log=True, n_pcs = 50)

# %%
sc.pp.neighbors(adata, n_pcs = 30)

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata)
# Out:
# /usr/local/lib/python3.10/dist-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   cax = scatter(

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !pip install leidenalg
# Out:
# Collecting leidenalg
#   Downloading leidenalg-0.10.1-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 19.3 MB/s eta 0:00:00
# Collecting igraph<0.11,>=0.10.0 (from leidenalg)
#   Downloading igraph-0.10.8-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 59.5 MB/s eta 0:00:00
# Collecting texttable>=1.6.2 (from igraph<0.11,>=0.10.0->leidenalg)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph, leidenalg
# Successfully installed igraph-0.10.8 leidenalg-0.10.1 texttable-1.7.0

# %%
sc.tl.leiden(adata, resolution = 0.5)

# %%
adata.obs
# Out:
#                     n_genes_by_counts  total_counts leiden
# TACGTCCCACGTGTGC                 1870   1956.289917     16
# AGTTCGAGTCATATGC                 1828   1929.712280     16
# GGGACTCTCCGAGATT                 1883   1950.066772     16
# CAACAACCATACCATG                 1868   1974.608643     16
# ATTTACCAGCTACTGT                 1876   1977.416382     16
# ...                               ...           ...    ...
# AGATCGTGTGTAGCAG                  205    494.030273     17
# TGGAACTGTTCCTACC-3                222    645.275391      3
# GACACGCTCTATACGG                  729   1065.135498     12
# ATGCATGCACATATGC                  801   1173.626221      0
# TCCGTGTTCTGGCCAG                  215    643.595459     17
#
# [46534 rows x 3 columns]

# %%
sorted_by_num_cells = adata.var['n_cells_by_counts'].sort_values(ascending=False)
sorted_by_num_cells
# Out:
# ENSG00000251562    46123
# ENSG00000198804    45943
# ENSG00000198712    45812
# ENSG00000198727    45560
# ENSG00000198763    44343
#                    ...
# ENSG00000145934     1275
# ENSG00000286932     1267
# ENSG00000261419     1211
# ENSG00000164749     1186
# ENSG00000163689     1151
# Name: n_cells_by_counts, Length: 2000, dtype: int64

# %%
sc.pl.umap(adata, color=['leiden'])
# Out:
# /usr/local/lib/python3.10/dist-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata, color=["ENSG00000167996", "ENSG00000278996", "ENSG00000111640"])

# %%
sc.tl.rank_genes_groups(adata, "leiden", method="t-test")
# Out:
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'names'] = self.var_names[global_indices]
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'scores'] = scores[global_indices]
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:401: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals'] = pvals[global_indices]
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:411: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals_adj'] = pvals_adj[global_indices]
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:422: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'logfoldchanges'] = np.log2(
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:396: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'names'] = self.var_names[global_indices]
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:398: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'scores'] = scores[global_indices]
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:401: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals'] = pvals[global_indices]
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:411: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'pvals_adj'] = pvals_adj[global_indices]
# /usr/local/lib/python3.10/dist-packages/scanpy/tools/_rank_genes_groups.py:422: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.stats[group_name, 'logfoldchanges'] = np.log2(

# %%
sc.pl.rank_genes_groups(adata, n_genes=10)

# %%
sc.pl.rank_genes_groups_heatmap(adata, groups="5", n_genes=10, groupby="leiden")
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_leiden). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
#  'ENSG00000125462' 'ENSG00000125148']
#
#
# Group: 14
# ['ENSG00000187323' 'ENSG00000198938' 'ENSG00000147862' 'ENSG00000198899'
#  'ENSG00000251562' 'ENSG00000100095' 'ENSG00000278996' 'ENSG00000210082'
#  'ENSG00000169862' 'ENSG00000175061']
#
#
# Group: 15
# ['ENSG00000210082' 'ENSG00000278996' 'ENSG00000251562' 'ENSG00000163618'
#  'ENSG00000215386' 'ENSG00000172264' 'ENSG00000124766' 'ENSG00000198899'
#  'ENSG00000147862' 'ENSG00000131711']
#
#
# Group: 16
# ['ENSG00000106278' 'ENSG00000184226' 'ENSG00000187416' 'ENSG00000110693'
#  'ENSG00000242808' 'ENSG00000046653' 'ENSG00000169760' 'ENSG00000148948'
#  'ENSG00000091129' 'ENSG00000150471']
#
#
# Group: 17
# ['ENSG00000137818' 'ENSG00000133112' 'ENSG00000205542' 'ENSG00000034510'
#  'ENSG00000087086' 'ENSG00000167526' 'ENSG00000231500' 'ENSG00000105372'
#  'ENSG00000229117' 'ENSG00000186468']
#
#
# Group: 18
# ['ENSG00000019582' 'ENSG00000065413' 'ENSG00000075884' 'ENSG00000158985'
#  'ENSG00000205542' 'ENSG00000081237' 'ENSG00000204287' 'ENSG00000137478'
#  'ENSG00000068305' 'ENSG00000152601']
#
#
# Group: 19
# ['ENSG00000106278' 'ENSG00000185565' 'ENSG00000168702' 'ENSG00000091129'
#  'ENSG00000184226' 'ENSG00000134121' 'ENSG00000102466' 'ENSG00000169760'
#  'ENSG00000175161' 'ENSG00000150471']
#
#
# Group: 20
# ['ENSG00000125730' 'ENSG00000081189' 'ENSG00000120594' 'ENSG00000019582'
#  'ENSG00000128512' 'ENSG00000068305' 'ENSG00000204287' 'ENSG00000148655'
#  'ENSG00000079215' 'ENSG00000100596']
#
#
# Group: 21
# ['ENSG00000187391' 'ENSG00000120885' 'ENSG00000122870' 'ENSG00000148053'
#  'ENSG00000069667' 'ENSG00000148498' 'ENSG00000189337' 'ENSG00000131018'
#  'ENSG00000245532' 'ENSG00000099204']

# %%
dat = pd.DataFrame({group + '_' + key[:1]: result[key][group] for group in groups for key in ['names', 'logfoldchanges','scores','pvals']})
dat.to_csv("/content/drive/MyDrive/Transcriptomics/SCPC/scanpy_integrated_lgg_nov30.csv")

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)

# %%
# !python /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py -d /content/drive/MyDrive/Transcriptomics/SCSA/whole_v2.db -i /content/drive/MyDrive/Transcriptomics/SCPC/scanpy_integrated_lgg_nov30.csv -s scanpy -g Human -f1.5 -p 0.01 -o /content/drive/MyDrive/Transcriptomics/SCPC/lgg_results_nov30.txt -m txt
# Out:
# Version V1.1 [2020/07/03]
# DB load: 47347 3 3 91969 37440
# Namespace(input='/content/drive/MyDrive/Transcriptomics/SCPC/scanpy_integrated_lgg_nov30.csv', output='/content/drive/MyDrive/Transcriptomics/SCPC/lgg_results_nov30.txt', db='/content/drive/MyDrive/Transcriptomics/SCSA/whole_v2.db', source='scanpy', cluster='all', MarkerDB=None, foldchange=1.5, pvalue=0.01, weight=100.0, species='Human', tissue='All', outfmt='txt', celltype='normal', target='cellmarker', Gensymbol=False, norefdb=False, noprint=False, list_tissue=False)
# Version V1.1 [2020/07/03]
# DB load: 47347 3 3 91969 37440
# load markers: 77000
# ############################## Cluster 0 ##############################
#
# Cell Num: 269
# Gene Num: 321
# Not Zero: 1424
# Cluster 0 Gene number: 361
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                Microglial cell        9.9806    1.4
# ------------------------------------------------------------
#                    (Monocyte)          (6.8931)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 321 Group2: 1375
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                                                  go_name
# GO:0004129        10             10 0.001568 0.687095   -                                            cytochrome-c oxidase activity
# GO:0008121         5              5 0.025833 0.687095   -                                ubiquinol-cytochrome-c reductase activity
# GO:0017127         4              3 0.027278 0.687095   -                                         cholesterol transporter activity
# GO:0042605         6              8 0.033679 0.687095   -                                                  peptide antigen binding
# GO:0001228        17             43 0.046925 0.687095   - DNA-binding transcription activator activity, RNA polymerase II-specific
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                      go_name
# GO:0035577         8              7 0.002821 0.555002   -   azurophil granule membrane
# GO:0005743        24             50 0.003225 0.555002   - mitochondrial inner membrane
# GO:0005765        17             32 0.005970 0.555002   -           lysosomal membrane
# GO:0070062        91            296 0.006066 0.555002   -        extracellular exosome
# GO:0005746         6              5 0.008621 0.631024   -    mitochondrial respirasome
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                   go_name
# GO:0043312        29             67 0.004111 0.658663   -                  neutrophil degranulation
# GO:0071222         9             11 0.006567 0.658663   -   cellular response to lipopolysaccharide
# GO:1902600        11             16 0.006762 0.658663   -            proton transmembrane transport
# GO:0010875         4              2 0.013718 0.658663   - positive regulation of cholesterol efflux
# GO:0009060         6              6 0.014538 0.658663   -                       aerobic respiration
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# Other Gene number: 1375
# ############################## Cluster 1 ##############################
#
# Cell Num: 200
# Gene Num: 116
# Not Zero: 660
# Cluster 1 Gene number: 134
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                Microglial cell        7.4743    1.1
# ------------------------------------------------------------
#                   (Macrophage)         (6.5787)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 116 Group2: 1418
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                                                  go_name
# GO:0017124         8             20 0.000724 0.199109   -                                                       SH3 domain binding
# GO:0042605         5              9 0.002612 0.357416   -                                                  peptide antigen binding
# GO:0001227         7             24 0.006740 0.357416   - DNA-binding transcription repressor activity, RNA polymerase II-specific
# GO:0001540         6             18 0.007147 0.357416   -                                                     amyloid-beta binding
# GO:0000978        10             47 0.008519 0.357416   -        RNA polymerase II proximal promoter sequence-specific DNA binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                    go_name
# GO:0000139        16             63 0.000153 0.032108   *                             Golgi membrane
# GO:0042613         5              5 0.000421 0.032765   *               MHC class II protein complex
# GO:0030669         6              9 0.000468 0.032765   * clathrin-coated endocytic vesicle membrane
# GO:0032588         6             12 0.001437 0.075427   -               trans-Golgi network membrane
# GO:0030658         5             10 0.003684 0.151168   -                 transport vesicle membrane
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                       go_name
# GO:0006955         7             19 0.002317 0.370358   -                               immune response
# GO:0043312        14             70 0.003092 0.370358   -                      neutrophil degranulation
# GO:0008203         4              6 0.004564 0.370358   -                 cholesterol metabolic process
# GO:0060333         5             12 0.006713 0.370358   -   interferon-gamma-mediated signaling pathway
# GO:1902430         3              3 0.007121 0.370358   - negative regulation of amyloid-beta formation
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# Other Gene number: 
ptor activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                               go_name
# GO:0030054        14             70 0.000301 0.058968   -                         cell junction
# GO:0005887        14             92 0.003293 0.312917   - integral component of plasma membrane
# GO:0043197         7             32 0.007231 0.312917   -                       dendritic spine
# GO:0043025        10             61 0.008322 0.312917   -                    neuronal cell body
# GO:0043198         3              5 0.009525 0.312917   -                       dendritic shaft
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                         go_name
# GO:0007409         6             14 0.000796 0.342584   -                                    axonogenesis
# GO:0001764         6             19 0.002842 0.342584   -                                neuron migration
# GO:0007420         6             20 0.003518 0.342584   -                               brain development
# GO:0035235         4              8 0.004218 0.342584   - ionotropic glutamate receptor signaling pathway
# GO:0000226         6             21 0.004307 0.342584   -           microtubule cytoskeleton organization
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# Other Gene number: 1418
# ############################## Cluster 15 ##############################
#
# Cell Num: 87
# Gene Num: 55
# Not Zero: 189
# Cluster 15 Gene number: 102
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                     Neuron            5.4081    1.2
# ------------------------------------------------------------
#                (Endothelial cell)      (4.5817)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 55 Group2: 1420
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                                                             go_name
# GO:0015631         3              7 0.004891 0.332293   -                                                                     tubulin binding
# GO:0004181         2              2 0.007808 0.332293   -                                                    metallocarboxypeptidase activity
# GO:0005200         4             20 0.010551 0.332293   -                                              structural constituent of cytoskeleton
# GO:0050839         2              9 0.060525 0.332293   -                                                      cell adhesion molecule binding
# GO:1904929         1              1 0.073210 0.332293   - coreceptor activity involved in Wnt signaling pathway, planar cell polarity pathway
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                    go_name
# GO:0030054        11             70 0.000115 0.009428  **                              cell junction
# GO:0098982         5             10 0.000136 0.009428  **                         GABA-ergic synapse
# GO:0030175         4             12 0.002258 0.065777   -                                 filopodium
# GO:0099056         3              5 0.002408 0.065777   - integral component of presynaptic membrane
# GO:0098978         8             59 0.002623 0.065777   -                      glutamatergic synapse
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                                         go_name
# GO:0007416         4             10 0.001313 0.251569   -                                                synapse assembly
# GO:0007155         7             43 0.001954 0.251569   -                                                   cell adhesion
# GO:0050807         3              5 0.002408 0.251569   -                              regulation of synapse organization
# GO:0031175         5             22 0.002587 0.251569   -                                   neuron projection development
# GO:0007156         4             15 0.004422 0.251569   - homophilic cell adhesion via plasma membrane adhesion molecules
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# Other Gene number: 1420
# ############################## Cluster 16 ##############################
#
# Cell Num: 268
# Gene Num: 652
# Not Zero: 1898
# Cluster 16 Gene number: 898
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                   Astrocyte           9.1321    1.2
# ------------------------------------------------------------
#                 (Oligodendrocyte)      (7.8191)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 652 Group2: 1403
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                                                                          go_name
# GO:0005516        21             29 0.079046 0.866816   -                                                                               calmodulin binding
# GO:0005509        37             61 0.115464 0.866816   -                                                                              calcium ion binding
# GO:0005198        14             19 0.127639 0.866816   -                                                                     structural molecule activity
# GO:1904315         6              6 0.146470 0.866816   - transmitter-gated ion channel activity involved in regulation of postsynaptic membrane potential
# GO:0030246        10             13 0.160164 0.866816   -                                                                             carbohydrate binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                               go_name
# GO:0030054        54             70 0.002892 0.834205   -                         cell junction
# GO:0005887        65             92 0.004992 0.834205   - integral component of plasma membrane
# GO:0005886       199            363 0.016283 0.834205   -                       plasma membrane
# GO:0030424        29             39 0.035421 0.834205   -                                  axon
# GO:0045211        24             31 0.040230 0.834205   -                 postsynaptic membrane
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                           go_name
# GO:0007155        35             43 0.008971  0.85751   -                     cell adhesion
# GO:0007399        33             43 0.019324  0.85751   -        nervous system development
# GO:0007411        24             32 0.049979  0.85751   -                     axon guidance
# GO:0001764        16             19 0.056569  0.85751   -                  neuron migration
# GO:0030198        17             21 0.061715  0.85751   - extracellular matrix organization
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# Other Gene number: 1403
# ############################## Cluster 17 ##############################
#
# Cell Num: 97
# Gene Num: 148
# Not Zero: 560
# Cluster 17 Gene number: 160
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                Microglial cell        5.8415    1.5
# ------------------------------------------------------------
#                    (Monocyte)          (3.8032)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 148 Group2: 1396
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num      p-value      q-value sig                              go_name
# GO:0003735        71             60 1.707654e-44 3.227467e-42 ***   structural constituent of ribosome
# GO:0003723        76            203 1.209789e-22 1.143251e-20 ***                          RNA binding
# GO:0019843         8              6 1.083742e-05 6.827577e-04 ***                         rRNA binding
# GO:0048027         7              7 1.248881e-04 5.900963e-03  **                  mRNA 5'-UTR binding
# GO:0070180         5              4 6.950535e-04 2.617301e-02   * large ribosomal subunit rRNA binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num      p-value      q-value sig                           go_name
# GO:0022625        43             34 2.355426e-26 4.074887e-24 *** cytosolic large ribosomal subunit
# GO:0022627        31             25 9.711096e-19 8.400098e-17 *** cytosolic small ribosomal subunit
# GO:0005925        43             93 1.954631e-14 1.127170e-12 ***                    focal adhesion
# GO:0042788        20             18 9.420666e-12 4.074438e-10 ***                polysomal ribosome
# GO:0005829       102            564 2.572630e-11 8.901300e-10 ***                           cytosol
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num      p-value      q-value sig                                                             go_name
# GO:0006614        72             57 1.832024e-46 1.192647e-43 ***         SRP-dependent cotranslational protein targeting to membrane
# GO:0006413        71             59 8.264537e-45 1.793404e-42 ***                                            translational initiation
# GO:0000184        71             59 8.264537e-45 1.793404e-42 *** nuclear-transcribed mRNA catabolic process, nonsense-mediated decay
# GO:0006412        71             61 3.496943e-44 5.691275e-42 ***                                                         translation
# GO:0002181        27             25 2.039912e-15 2.655965e-13 ***                                             cytoplasmic translation
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# Other Gene number: 1396
# ############################## Cluster 18 ##############################
#
# Cell Num: 106
# Gene Num: 77
# Not Zero: 320
# Cluster 18 Gene number: 83
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                     B cell            5.4413    1.3
# ------------------------------------------------------------
#                   (Macrophage)         (4.2716)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 77 Group2: 1417
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                              go_name
# GO:0042605         4              9 0.003271  0.27788   -              peptide antigen binding
# GO:0046875         3              4 0.003968  0.27788   -              ephrin receptor binding
# GO:0032395         2              2 0.014706  0.27788   -       MHC class II receptor activity
# GO:0042609         2              2 0.014706  0.27788   -                 CD4 receptor binding
# GO:0023026         3              8 0.016101  0.27788   - MHC class II protein complex binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                                              go_name
# GO:0042613         5              5 0.000066 0.006588  **                                         MHC class II protein complex
# GO:0030658         6             10 0.000082 0.006588  **                                           transport vesicle membrane
# GO:0030669         5              9 0.000444 0.023819   *                           clathrin-coated endocytic vesicle membrane
# GO:0071556         5             11 0.000892 0.035918   * integral component of lumenal side of endoplasmic reticulum membrane
# GO:0032588         5             12 0.001214 0.039079   *                                         trans-Golgi network membrane
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                               go_name
# GO:0050852         6             15 0.000450 0.168475   -                     T cell receptor signaling pathway
# GO:0050900         6             15 0.000450 0.168475   -                                   leukocyte migration
# GO:0014066         4              6 0.001082 0.226949   - regulation of phosphatidylinositol 3-kinase signaling
# GO:0060333         5             12 0.001214 0.226949   -           interferon-gamma-mediated signaling pathway
# GO:0007165        13             96 0.002789 0.293759   -                                   signal transduction
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# Other Gene number: 1417
# ############################## Cluster 19 ##############################
#
# Cell Num: 252
# Gene Num: 548
# Not Zero: 1582
# Cluster 19 Gene number: 800
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                   Astrocyte           9.9308    1.7
# ------------------------------------------------------------
#                 (Oligodendrocyte)      (5.8559)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 548 Group2: 1401
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                                                                          go_name
# GO:0005516        19             29 0.055099 0.820278   -                                                                               calmodulin binding
# GO:0005509        34             61 0.058369 0.820278   -                                                                              calcium ion binding
# GO:1904315         6              6 0.089617 0.820278   - transmitter-gated ion channel activity involved in regulation of postsynaptic membrane potential
# GO:0030165         8             10 0.102428 0.820278   -                                                                               PDZ domain binding
# GO:0005088         8             10 0.102428 0.820278   -                                                   Ras guanyl-nucleotide exchange factor activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                               go_name
# GO:0005887        61             90 0.000477 0.233353   - integral component of plasma membrane
# GO:0030054        49             70 0.001069 0.261395   -                         cell junction
# GO:0005886       177            361 0.002396 0.390614   -                       plasma membrane
# GO:0098978        37             57 0.010425 0.821123   -                 glutamatergic synapse
# GO:0030424        27             39 0.015590 0.821123   -                                  axon
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                        go_name
# GO:0007155        33             43 0.002555 0.815409   -                  cell adhesion
# GO:0007268        20             21 0.003641 0.815409   - chemical synaptic transmission
# GO:0007399        30             43 0.010274 0.815409   -     nervous system development
# GO:0007411        23             31 0.014591 0.815409   -                  axon guidance
# GO:0001764        16             19 0.018879 0.815409   -               neuron migration
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# Other Gene number: 1401
# ############################## Cluster 2 ##############################
#
# Cell Num: 106
# Gene Num: 47
# Not Zero: 246
# Cluster 2 Gene number: 58
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                Microglial cell        5.9039    1.1
# ------------------------------------------------------------
#                   (Macrophage)         (5.4059)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 47 Group2: 1420
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                           go_name
# GO:0017124         5             20 0.000893 0.156319   -                                SH3 domain binding
# GO:0005085         4             18 0.004431 0.245276   -        guanyl-nucleotide exchange factor activity
# GO:0033613         2              4 0.013885 0.245276   -           activating transcription factor binding
# GO:0050750         2              5 0.019045 0.245276   - low-density lipoprotein particle receptor binding
# GO:0048365         2              6 0.024879 0.245276   -                                Rac GTPase binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                    go_name
# GO:0030669         3              9 0.005538 0.324759   - clathrin-coated endocytic vesicle membrane
# GO:0032588         3             12 0.010704 0.324759   -               trans-Golgi network membrane
# GO:0032045         2              4 0.013885 0.324759   -  guanyl-nucleotide exchange factor complex
# GO:0042613         2              5 0.019045 0.324759   -               MHC class II protein complex
# GO:0005886        18            366 0.043434 0.324759   -                            plasma membrane
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                                                                                             go_name
# GO:0071805         3              7 0.003160 0.200129   -                                                                               potassium ion transmembrane transport
# GO:0007186         6             42 0.003456 0.200129   -                                                                        G protein-coupled receptor signaling pathway
# GO:0006811         3              8 0.004248 0.200129   -                                                                                                       ion transport
# GO:0030036         4             18 0.004431 0.200129   -                                                                                     actin cytoskeleton organization
# GO:1902961         2              2 0.005787 0.200129   - positive regulation of aspartic-type endopeptidase activity involved in amyloid precursor protein catabolic process
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# Other Gene number: 1420
# ############################## Cluster 20 ##############################
#
# Cell Num: 232
# Gene Num: 320
# Not Zero: 1133
# Cluster 20 Gene number: 398
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                Microglial cell        8.5050    1.2
# ------------------------------------------------------------
#                   (Macrophage)         (6.8729)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 320 Group2: 1347
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                                                      go_name
# GO:0001664         7              9 0.020983 0.652093   -                                           G protein-coupled receptor binding
# GO:0001227        11             23 0.046260 0.652093   -     DNA-binding transcription repressor activity, RNA polymerase II-specific
# GO:1990841         4              4 0.048781 0.652093   -                                          promoter-specific chromatin binding
# GO:0031683         4              4 0.048781 0.652093   -                                 G-protein beta/gamma-subunit complex binding
# GO:0043027         3              2 0.051665 0.652093   - cysteine-type endopeptidase inhibitor activity involved in apoptotic process
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                    go_name
# GO:0000139        28             59 0.002109 0.610797   -                             Golgi membrane
# GO:0032588         9             10 0.004768 0.610797   -               trans-Golgi network membrane
# GO:0030669         8              8 0.005176 0.610797   - clathrin-coated endocytic vesicle membrane
# GO:0012507         9             13 0.014929 0.797616   -     ER to Golgi transport vesicle membrane
# GO:0005765        15             30 0.016284 0.797616   -                         lysosomal membrane
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                                                           go_name
# GO:0019886        10             15 0.012456 0.657223   - antigen processing and presentation of exogenous peptide antigen via MHC class II
# GO:0070106         3              1 0.024068 0.657223   -                                         interleukin-27-mediated signaling pathway
# GO:0070757         3              1 0.024068 0.657223   -                                         interleukin-35-mediated signaling pathway
# GO:0045893        21             51 0.024376 0.657223   -                               positive regulation of transcription, DNA-templated
# GO:0060333         8             12 0.024820 0.657223   -                                       interferon-gamma-mediated signaling pathway
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# Other Gene number: 1347
# ############################## Cluster 21 ##############################
#
# Cell Num: 196
# Gene Num: 446
# Not Zero: 1237
# Cluster 21 Gene number: 625
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good                Astrocyte           12.1066   3.6
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 446 Group2: 1364
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                                       go_name
# GO:0008270        34             63 0.011931 0.838823   -                                              zinc ion binding
# GO:0003700        30             59 0.030921 0.838823   -                     DNA-binding transcription factor activity
# GO:0000976         5              4 0.045764 0.838823   - transcription regulatory region sequence-specific DNA binding
# GO:0004521         3              1 0.048594 0.838823   -                                     endoribonuclease activity
# GO:0005088         7             10 0.099461 0.838823   -                Ras guanyl-nucleotide exchange factor activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# ...
# GO:0008544         2              3 0.001788 0.096093   -                   epidermis development
# GO:0006913         2              4 0.002660 0.096093   -             nucleocytoplasmic transport
# GO:1900034         2              5 0.003693 0.096093   - regulation of cellular response to heat
# GO:0006986         2              7 0.006226 0.096093   -            response to unfolded protein
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# Other Gene number: 1420
# ############################## Cluster 6 ##############################
#
# Cell Num: 74
# Gene Num: 54
# Not Zero: 172
# Cluster 6 Gene number: 59
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                  Immune cell          4.1849    1.2
# ------------------------------------------------------------
#           (Natural killer T (NKT) cell)(3.4701)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 54 Group2: 1420
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                go_name
# GO:0030507         3              5 0.002287 0.151470   -                       spectrin binding
# GO:0005096         6             35 0.003048 0.151470   -              GTPase activator activity
# GO:0019888         3              6 0.003341 0.151470   - protein phosphatase regulator activity
# GO:0001223         2              3 0.012274 0.264472   -      transcription coactivator binding
# GO:0005521         2              3 0.012274 0.264472   -                          lamin binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                       go_name
# GO:0000159         2              2 0.007541 0.441876   -           protein phosphatase type 2A complex
# GO:0031965         4             21 0.011487 0.441876   -                              nuclear membrane
# GO:0099092         2              3 0.012274 0.441876   - postsynaptic density, intracellular component
# GO:0042995         3             13 0.018564 0.445199   -                               cell projection
# GO:0044853         2              5 0.024587 0.445199   -                          plasma membrane raft
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                               go_name
# GO:0014066         4              6 0.000287 0.160362   - regulation of phosphatidylinositol 3-kinase signaling
# GO:0006470         5             21 0.002002 0.237536   -                             protein dephosphorylation
# GO:0043666         3              6 0.003341 0.237536   -     regulation of phosphoprotein phosphatase activity
# GO:0007165        10             96 0.003942 0.237536   -                                   signal transduction
# GO:0070166         2              2 0.007541 0.237536   -                                 enamel mineralization
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# Other Gene number: 1420
# ############################## Cluster 7 ##############################
#
# Cell Num: 221
# Gene Num: 374
# Not Zero: 1107
# Cluster 7 Gene number: 583
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?                   Astrocyte           8.5557    1.4
# ------------------------------------------------------------
#                     (Neuron)           (6.2164)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 374 Group2: 1421
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                                                                                          go_name
# GO:1904315         6              6 0.023179 0.734181   - transmitter-gated ion channel activity involved in regulation of postsynaptic membrane potential
# GO:0050839         7              9 0.032227 0.734181   -                                                                   cell adhesion molecule binding
# GO:0004714         5              5 0.038199 0.734181   -                                          transmembrane receptor protein tyrosine kinase activity
# GO:0005201         5              5 0.038199 0.734181   -                                                      extracellular matrix structural constituent
# GO:0005509        25             61 0.040292 0.734181   -                                                                              calcium ion binding
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                               go_name
# GO:0005887        52             92 0.000007 0.002712  ** integral component of plasma membrane
# GO:0030054        40             70 0.000076 0.014476   *                         cell junction
# GO:0005886       133            366 0.000136 0.017242   *                       plasma membrane
# GO:0045211        22             31 0.000423 0.040337   *                 postsynaptic membrane
# GO:0098978        30             59 0.002585 0.196980   -                 glutamatergic synapse
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num  p-value  q-value sig                        go_name
# GO:0007155        32             43 0.000010 0.018795   *                  cell adhesion
# GO:0001764        16             19 0.000745 0.578347   -               neuron migration
# GO:0007411        21             32 0.001192 0.578347   -                  axon guidance
# GO:0007399        25             43 0.001501 0.578347   -     nervous system development
# GO:0007268        16             21 0.001559 0.578347   - chemical synaptic transmission
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# Other Gene number: 1421
# ############################## Cluster 8 ##############################
#
# Cell Num: 139
# Gene Num: 192
# Not Zero: 668
# Cluster 8 Gene number: 207
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# Good       Natural killer T (NKT) cell  8.5054    2.4
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 192 Group2: 1405
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num      p-value      q-value sig                                   go_name
# GO:0003735        39             79 2.504903e-10 7.164022e-08 ***        structural constituent of ribosome
# GO:0003723        54            222 4.333025e-05 6.196226e-03  **                               RNA binding
# GO:0004129         6             11 1.104409e-02 6.046278e-01   -             cytochrome-c oxidase activity
# GO:0003729         7             22 5.041974e-02 6.046278e-01   -                              mRNA binding
# GO:0008121         3              5 6.061170e-02 6.046278e-01   - ubiquinol-cytochrome-c reductase activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num      p-value  q-value sig                                                  go_name
# GO:0022625        26             45 3.361025e-08 0.000005 ***                        cytosolic large ribosomal subunit
# GO:0005829       119            578 4.045640e-08 0.000005 ***                                                  cytosol
# GO:0042788        13             22 9.814244e-05 0.007884  **                                       polysomal ribosome
# GO:0022627        15             34 3.504861e-04 0.021117   *                        cytosolic small ribosomal subunit
# GO:0098556         4              4 9.590517e-03 0.462263   - cytoplasmic side of rough endoplasmic reticulum membrane
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num      p-value      q-value sig                                                             go_name
# GO:0006413        41             78 1.666885e-11 1.640661e-08 ***                                            translational initiation
# GO:0006614        40             76 3.021476e-11 1.640661e-08 ***         SRP-dependent cotranslational protein targeting to membrane
# GO:0000184        39             78 1.863208e-10 6.744813e-08 *** nuclear-transcribed mRNA catabolic process, nonsense-mediated decay
# GO:0006412        39             80 3.353489e-10 9.104722e-08 ***                                                         translation
# GO:0002181        17             30 1.187088e-05 2.578355e-03  **                                             cytoplasmic translation
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# Other Gene number: 1405
# ############################## Cluster 9 ##############################
#
# Cell Num: 89
# Gene Num: 85
# Not Zero: 325
# Cluster 9 Gene number: 93
# ------------------------------------------------------------
# Type                Cell Type           Score     Times
# ------------------------------------------------------------
# ?          Natural killer T (NKT) cell  5.0057    1.3
# ------------------------------------------------------------
#                 (Microglial cell)      (3.8116)
# ------------------------------------------------------------
#
# Go Enrichment analysis: Group1: 85 Group2: 1420
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Function <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num      p-value      q-value sig                                go_name
# GO:0003735        27             78 9.810516e-13 1.785514e-10 ***     structural constituent of ribosome
# GO:0003723        36            223 1.625026e-08 1.478774e-06 ***                            RNA binding
# GO:0005515        68            932 3.500521e-03 2.123650e-01   -                        protein binding
# GO:0030507         3              5 7.922717e-03 3.376886e-01   -                       spectrin binding
# GO:0019888         3              6 1.140329e-02 3.376886e-01   - protein phosphatase regulator activity
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Component <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num      p-value  q-value sig                           go_name
# GO:0022627        14             34 1.170549e-07 0.000017 *** cytosolic small ribosomal subunit
# GO:0022625        15             44 2.955751e-07 0.000021 *** cytosolic large ribosomal subunit
# GO:0005829        58            587 1.057025e-06 0.000051 ***                           cytosol
# GO:0042788         7             21 6.429074e-04 0.023145   *                polysomal ribosome
# GO:0016020        30            288 1.354406e-03 0.039007   *                          membrane
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>> Process <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#        ids  gene_num  othergene_num      p-value      q-value sig                                                             go_name
# GO:0006614        27             75 4.494831e-13 1.583514e-10 ***         SRP-dependent cotranslational protein targeting to membrane
# GO:0006413        27             77 7.588727e-13 1.583514e-10 ***                                            translational initiation
# GO:0000184        27             77 7.588727e-13 1.583514e-10 *** nuclear-transcribed mRNA catabolic process, nonsense-mediated decay
# GO:0006412        27             79 1.264119e-12 1.978346e-10 ***                                                         translation
# GO:0002181        11             29 5.885854e-06 7.369089e-04 ***                                             cytoplasmic translation
# /content/drive/MyDrive/Transcriptomics/SCSA/SCSA.py:228: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_outs = all_outs.append(outs)
#
# Other Gene number: 1420
# ################################################################################
#
# #Cluster Type Celltype Score Times
# ['0', '?', 'Microglial cell|Monocyte', '9.980571215183067|6.8931419655230055', 1.4478986890306718]
# ['1', '?', 'Microglial cell|Macrophage', '7.474290942929584|6.5787425108038295', 1.1361276004730472]
# ['10', '?', 'Microglial cell|Macrophage', '5.275002278219093|5.143930758336565', 1.0254808095288035]
# ['11', '?', 'Astrocyte|Oligodendrocyte', '10.89700361505461|6.401085133216461', 1.7023681748127304]
# ['12', 'Good', 'Monocyte', 8.481796690219051, 2.742514640147275]
# ['13', 'Good', 'Astrocyte', 12.42913809859876, 2.9859560016062128]
# ['14', '?', 'Neuron|Natural killer cell', '8.11939596359866|4.780565393499859', 1.6984175082383797]
# ['15', '?', 'Neuron|Endothelial cell', '5.408102092087815|4.5817215928322295', 1.1803646255041769]
# ['16', '?', 'Astrocyte|Oligodendrocyte', '9.132065321153517|7.8190625163819965', 1.1679233030840463]
# ['17', '?', 'Microglial cell|Monocyte', '5.841526211016231|3.8031792325497156', 1.5359586950363033]
# ['18', '?', 'B cell|Macrophage', '5.441319263036106|4.2716020599445805', 1.2738357147216801]
# ['19', '?', 'Astrocyte|Oligodendrocyte', '9.930808986142289|5.8559427286080385', 1.6958514531959654]
# ['2', '?', 'Microglial cell|Macrophage', '5.903895240869219|5.405918179975189', 1.0921170177415291]
# ['20', '?', 'Microglial cell|Macrophage', '8.504964326979687|6.87290936632863', 1.237462022800232]
# ['21', 'Good', 'Astrocyte', 12.106557901917883, 3.570318649196521]
# ['3', '?', 'Naive T(Th0) cell|Microglial cell', '3.6206669315825244|2.9049543511706344', 1.2463765326031624]
# ['4', '?', 'Microglial cell|Macrophage', '8.596241382341438|5.535684308346584', 1.5528778202507345]
# ['5', '?', 'Naive T(Th0) cell|Microglial cell', '3.3568698571624958|3.0386929745482347', 1.1047084668570588]
# ['6', '?', 'Immune cell|Natural killer T (NKT) cell', '4.184877884030465|3.4701344195577404', 1.2059699648648818]
# ['7', '?', 'Astrocyte|Neuron', '8.55568958881126|6.216370376523484', 1.3763159320626008]
# ['8', 'Good', 'Natural killer T (NKT) cell', 8.505432386121804, 2.3597413417244546]
# ['9', '?', 'Natural killer T (NKT) cell|Microglial cell', '5.005701209901629|3.811596804045337', 1.3132819307091874]

# %%
# Read the text document into a DataFrame
df = pd.read_csv('/content/drive/MyDrive/Transcriptomics/SCPC/lgg_results_nov30.txt', sep='\t')

# %%
df
# Out:
#                                               Cell Type   Z-score  Cluster
# 0                                       Microglial cell  9.980571        0
# 1                                              Monocyte  6.893142        0
# 2                                            Macrophage  6.623116        0
# 3                                        Dendritic cell  4.976064        0
# 4                                                B cell  3.712031        0
# ...                                                 ...       ...      ...
# 3365  Lymphoid-primed multipotent progenitor cell(LMPP) -0.485852        9
# 3366                                  Beta cell(β cell) -0.486524        9
# 3367                                       Stromal cell -0.488029        9
# 3368                                      Ciliated cell -0.489068        9
# 3369                    Oligodendrocyte progenitor cell -0.489087        9
#
# [3370 rows x 3 columns]

# %%
df['Z-score'] = df['Z-score'].fillna(0)

# Group the data by "Cluster" and find the cell type with the highest Z-score in each group
highest_zscores = df.groupby('Cluster')['Z-score'].idxmax()

# Extract the corresponding cell types for the highest Z-scores
cell_types_with_highest_zscores = df.loc[highest_zscores, 'Cell Type'].tolist()

# %%
cell_types_with_highest_zscores
# Out:
# ['Microglial cell',
#  'Microglial cell',
#  'Microglial cell',
#  'Naive T(Th0) cell',
#  'Microglial cell',
#  'Naive T(Th0) cell',
#  'Immune cell',
#  'Astrocyte',
#  'Natural killer T (NKT) cell',
#  'Natural killer T (NKT) cell',
#  'Microglial cell',
#  'Astrocyte',
#  'Monocyte',
#  'Astrocyte',
#  'Neuron',
#  'Neuron',
#  'Astrocyte',
#  'Microglial cell',
#  'B cell',
#  'Astrocyte',
#  'Microglial cell',
#  'Astrocyte']

# %%
cluster_to_cell_type = {cluster_num: cell_type for cluster_num, cell_type in enumerate(cell_types_with_highest_zscores)}
cluster_to_cell_type
# Out:
# {0: 'Microglial cell',
#  1: 'Microglial cell',
#  2: 'Microglial cell',
#  3: 'Naive T(Th0) cell',
#  4: 'Microglial cell',
#  5: 'Naive T(Th0) cell',
#  6: 'Immune cell',
#  7: 'Astrocyte',
#  8: 'Natural killer T (NKT) cell',
#  9: 'Natural killer T (NKT) cell',
#  10: 'Microglial cell',
#  11: 'Astrocyte',
#  12: 'Monocyte',
#  13: 'Astrocyte',
#  14: 'Neuron',
#  15: 'Neuron',
#  16: 'Astrocyte',
#  17: 'Microglial cell',
#  18: 'B cell',
#  19: 'Astrocyte',
#  20: 'Microglial cell',
#  21: 'Astrocyte'}

# %%
adata.obs['leiden']
# Out:
# TACGTCCCACGTGTGC      16
# AGTTCGAGTCATATGC      16
# GGGACTCTCCGAGATT      16
# CAACAACCATACCATG      16
# ATTTACCAGCTACTGT      16
#                       ..
# AGATCGTGTGTAGCAG      17
# TGGAACTGTTCCTACC-3     3
# GACACGCTCTATACGG      12
# ATGCATGCACATATGC       0
# TCCGTGTTCTGGCCAG      17
# Name: leiden, Length: 46534, dtype: category
# Categories (22, object): ['0', '1', '2', '3', ..., '18', '19', '20', '21']

# %%
adata.obs['leiden'] = adata.obs['leiden'].astype(int)

# %%
adata.obs['cell_types'] = adata.obs['leiden'].map(cluster_to_cell_type)

# %%
adata.obs
# Out:
#                     n_genes_by_counts  total_counts  leiden         cell_types
# TACGTCCCACGTGTGC                 1870   1956.289917      16          Astrocyte
# AGTTCGAGTCATATGC                 1828   1929.712280      16          Astrocyte
# GGGACTCTCCGAGATT                 1883   1950.066772      16          Astrocyte
# CAACAACCATACCATG                 1868   1974.608643      16          Astrocyte
# ATTTACCAGCTACTGT                 1876   1977.416382      16          Astrocyte
# ...                               ...           ...     ...                ...
# AGATCGTGTGTAGCAG                  205    494.030273      17    Microglial cell
# TGGAACTGTTCCTACC-3                222    645.275391       3  Naive T(Th0) cell
# GACACGCTCTATACGG                  729   1065.135498      12           Monocyte
# ATGCATGCACATATGC                  801   1173.626221       0    Microglial cell
# TCCGTGTTCTGGCCAG                  215    643.595459      17    Microglial cell
#
# [46534 rows x 4 columns]

# %%
sc.pl.umap(adata, color=['leiden', 'cell_types'])
# Out:
# /usr/local/lib/python3.10/dist-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
from matplotlib.pyplot import rc_context
with rc_context({'figure.figsize': (8,8)}):
    sc.pl.umap(adata, color = ['cell_types'], frameon = False, s = 5, legend_loc = 'on data',
              legend_fontsize=12, legend_fontoutline=2)
# Out:
# /usr/local/lib/python3.10/dist-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
